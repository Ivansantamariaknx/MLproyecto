# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Predicción de datos con nuestro modelo escogido

# %%
import joblib

new_model = joblib.load(r"D:\Bootcamp\MLproyecto\Notebooks\new_model.pkl")

# %%
apredecir=pd.read_csv(r"D:\Bootcamp\MLproyecto\Data\Processed\ApredecirML.csv", sep=";")
apredecir.shape
# Out:
# (18, 5)

# %%
x_pred=apredecir

# %%
y_pred=new_model.predict(x_pred)

# %%
apredecir["Resultado"]= y_pred
apredecir
# Out:
#     MES  COMERCIAL_NUM  TELEOP_NUM  CANAL_NUM  tipodeobra  Resultado
# 0   500              7           5          1           3          0
# 1   500              3           1          3           3          0
# 2   500              1           9          1           1          0
# 3   500              3           5          1           5          0
# 4   500              2           9          1           1          0
# 5   500              7           1          3           5          1
# 6   500              3           4          1           5          0
# 7   500              3           5          1           5          0
# 8   500              3           5          1           3          0
# 9   500              3           1          3           5          0
# 10  500              7           4          1           1          0
# 11  600              1           1          3           1          1
# 12  600              1           3          1           5          0
# ...

# %%
ruta="D:\Bootcamp\MLproyecto\Data\Processed\prediccion.csv"
apredecir.to_csv(ruta, index=False)
